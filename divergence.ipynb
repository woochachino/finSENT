# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %%
hist = yf.Ticker("CAD=X").history(period="1y")["Close"]
print(hist)

plt.plot(hist.index, hist.values)
plt.title("USD/CAD Exchange Rate Over the Past Year")
# Out:
# Date
# 2025-01-07 00:00:00+00:00    1.43386
# 2025-01-08 00:00:00+00:00    1.43641
# 2025-01-09 00:00:00+00:00    1.43770
# 2025-01-10 00:00:00+00:00    1.44016
# 2025-01-13 00:00:00+00:00    1.44149
#                               ...
# 2025-12-31 00:00:00+00:00    1.36947
# 2026-01-02 00:00:00+00:00    1.37160
# 2026-01-05 00:00:00+00:00    1.37467
# 2026-01-06 00:00:00+00:00    1.37725
# 2026-01-07 00:00:00+00:00    1.38154
# Name: Close, Length: 258, dtype: float64
# Text(0.5, 1.0, 'USD/CAD Exchange Rate Over the Past Year')
